# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

import statsmodels.formula.api as sm


# %matplotlib inline

# %%
building = pd.read_csv('data/com.csv')
building.head(5)
# Out:
#              ptype  floora_plan  year  occ   es  site_EUI  n_site_gas  \
# 0      Multifamily     412503.0  1903  100   93      32.0     20472.0
# 1  General Medical     567517.0  1950  100   80     352.7   1255514.1
# 2      Multifamily     321464.0  1939  100   72      76.2      8906.3
# 3      Multifamily      54913.0  1911  100  100      17.9       601.0
# 4      Multifamily     175885.0  1973  100   40      56.2     39028.3
#
#    n_site_elec  water_use
# 0    3249755.2    22061.0
# 1   18295844.6     9574.0
# 2    1121931.8     5915.6
# 3     262377.2      231.9
# 4    1887619.4      237.9

# %% [markdown]
# #### Define X, Y variables
# ___

# %%
x_columns = ['ptype', 'floora_plan', 'year', 'occ', 'es', 'n_site_gas', 'n_site_elec', 'water_use']
y_columns = ['site_EUI']

X = building[x_columns].values
y = building[y_columns].values

# %%
X_df = building.loc[:, x_columns]

# %% [markdown]
# #### Correlations
# ___

# %% [markdown]
# #### X variables corelation
# ___

# %%
plt.figure(figsize=(24,12))

sns.heatmap(X_df.corr(), annot=True, annot_kws={"size": 7}, cmap='YlGnBu')
plt.show()

# %% [markdown]
# #### X vs Y variables corelation
# ___

# %%
plt.figure(figsize=(24,12))

sns.heatmap(building.corr(), annot=True, annot_kws={"size": 7}, cmap='YlGnBu')
plt.show()
